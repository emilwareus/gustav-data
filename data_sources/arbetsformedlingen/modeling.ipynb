# %%
from dask.distributed import Client
client = Client(n_workers=8, threads_per_worker=2, processes=False, memory_limit='2GB') #'
client
# Out:
# <Client: 'inproc://172.23.72.104/2734/1' processes=8 threads=16, memory=16.00 GB>

# %%
import dask.dataframe as dd

df = dd.read_csv('af_prepro.csv', encoding='iso-8859-1',
                 dtype={
                        'application_details_url': 'object',
                        'employment_type_label': 'object',
                        'employer_workplace': 'object',
                        'external_id': 'object',
                        'salary_description': 'object',
                        'workplace_address_street_address' : 'object',
                        'salary_type_label' : 'object',
                         'id' : 'object'
                    }, lineterminator='\n', n)
df
# Out:
# Dask DataFrame Structure:
#                 Unnamed: 0 application_deadline external_id headline      id last_publication_date number_of_vacancies publication_date salary_description application_details_url description_company_information description_conditions description_text duration_label employer_name employer_workplace employment_type_label occupation_legacy_ams_taxonomy_id salary_type_label working_hours_type_label workplace_address_city workplace_address_country workplace_address_postcode workplace_address_street_address other_old_legacy_attributes_ARBETSDRIFT other_old_legacy_attributes_DXA other_old_legacy_attributes_BIL_KRAV other_old_legacy_attributes_TILLTRADE
# npartitions=200
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0 application_deadline external_id  \
# 0           0           2006-05-16         NaN
# 1           1           2006-07-01         NaN
# 2           2           2006-07-14         NaN
# 3           3           2006-08-30         NaN
# 4           4           2006-07-31         NaN
# 5           5           2006-08-30         NaN
# 6           6           2006-10-25         NaN
# 7           7           2006-10-25         NaN
# 8           8           2006-10-25         NaN
# 9           9           2006-10-25         NaN
#
#                                 headline   id last_publication_date  \
# 0      Jobba i Norge med Manpower Helse!  NaN            2006-05-16
# 1                          Au Pair i Rom  NaN            2006-07-01
# 2                           Teknisk chef  NaN            2006-07-14
# 3        OPERASJONSSYKEPLEIERE TIL NORGE  NaN            2006-08-30
# 4      Jobba som värvare för Greenpeace!  NaN            2006-07-31
# ...

# %% [markdown]
# Hur är relationen heltid/deltid osv..?

# %%
res = df.working_hours_type_label.value_counts().compute()
# Out:
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 1.41 GB -- Worker memory limit: 2.00 GB
# distributed.worker - WARNING - Worker is at 156% memory usage. Pausing worker.  Process memory: 3.13 GB -- Worker memory limit: 2.00 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 3.13 GB -- Worker memory limit: 2.00 GB
# distributed.worker - WARNING - Worker is at 164% memory usage. Pausing worker.  Process memory: 3.29 GB -- Worker memory limit: 2.00 GB
# distributed.worker - WARNING - Memory use is high but worker has no data to store to disk.  Perhaps some other process is leaking memory?  Process memory: 3.29 GB -- Worker memory limit: 2.00 GB
# ...
