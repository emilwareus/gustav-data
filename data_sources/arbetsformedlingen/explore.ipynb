# %%
from tqdm import tqdm
import pandas as pd
import json
import os
import numpy as np

# %%
# All downloaded files 
os.listdir("downloads")
# Out:
# ['2006.json',
#  '2007.json',
#  '2008.json',
#  '2009.json',
#  '2010.json',
#  '2011.json',
#  '2012.json',
#  '2013.json',
#  '2014.json',
#  '2015.json',
#  '2016.json',
#  '2017.json',
#  '2018.json',
#  '2019.json']

# %% [markdown]
# ## Utforskande analys
#
# Vi börjar med att kolla på 2019, då vi tidigt såg att 2019 hade bäst data

# %%
def open_file(filename):
    with open(filename) as f:
        output = json.loads(f.read())
        
    return output

af_19 = open_file("./downloads/2019.json")

# %%
af_19[0]
# Out:
# {'access': None,
#  'access_to_own_car': None,
#  'application_deadline': '2019-01-02 23:59:59,000000000',
#  'application_details': {'email': None,
#   'information': None,
#   'other': None,
#   'reference': None,
#   'url': 'https://vgregion.mynetworkglobal.com/what:job/jobID:226557/type:job/where:1/apply:1',
#   'via_af': None},
#  'description': {'company_information': '',
#   'conditions': ' 100. Tillträde: 2018-10-01\r\ntillsvidareanställning',
#   'needs': None,
#   'requirements': None,
#   'text': 'Vill du bidra till att skapa Sveriges bästa hälso-och sjukvård och ett hållbart samhälle med tillväxt i hela Västra Götaland?Som Västra Götalandsregionens (VGR) IT-organisation är VGR IT:s uppgift att skapa de rätta tekniska förutsättningarna för VGR:s 53 000 medarbetare, både idag och i framtidens vårdinformationsmiljö.   Vi är\xa0600 medarbetare som varje dag är med och gör skillnad för patienter, medarbetare, besökare och invånare genom att ansvara för drift, support, förvaltning och utveckling av IT-stöden som används i VGR:s verksamheter.Läs mer på www.vgregion.se/it   Ditt uppdrag   Vad kan vi erbjuda dig?   Som en av Sveriges största arbetsgivare kan vi erbjuda rätt person goda karriär- och utvecklingsmöjligheter.Hos oss får du chansen att utföra ett meningsfullt arbete för samhället där du med dina insatser bidrar till Västra Götalandsregionens vision ”det goda livet”, samtidigt som du får ett intressant arbetsinnehåll.Vi eftersträvar en god balans mellan arbetsliv och privatliv och värnar om våra medarbetares hälsa.Läs mer om våra förmåner här: http://www.vgregion.se/jobba-i-vgr/sa-ar-det-att-jobba-hos-oss/dinaformaner/   Vilka kvalifikationer ska du ha?   Vi ser att det är meriterande om du har:   Vem är du?   Det är viktigt för oss att du har en helhetssyn samt att du står bakom och kan arbeta utifrån vår värdegrund:    - Tillsammans gör vi varandra framgångsrika.    - Vi lyssnar in.Vi lyssnar av.    - Feedback bidrar till vår utveckling.   Övrigt   Som organisation eftersträvar vi jämlikhet där alla medarbetare ska ha lika möjligheter och rättigheter till att utvecklas, göra ett bra arbete och trivas på arbetsplatsen.   Om Västra Götalandsregionen   Västra Götalandsregionen finns till för människorna i Västra Götaland.Vi ser till att det finns god hälso- och sjukvård för alla.Vi arbetar för en hållbar utveckling och tillväxt, bra miljö, förbättrad folkhälsa, ett rikt kulturliv och goda kommunikationer i hela Västra Götaland.   Ansökan   Västra Götalandsregionen ser helst att du registrerar din ansökan via rekryteringssystemet.Om du som sökande har frågor om den utannonserade tjänsten eller av särskilda och speciella skäl inte kan registrera dina uppgifter i ett offentligt system - kontakta kontaktperson för respektive annons.   Till bemannings-, förmedlings- och rekryteringsföretag och till dig som är försäljare:   Vi undanber oss vänligen men bestämt direktkontakt med bemannings-, förmedlings- och rekryteringsföretag samt andra externa aktörer och försäljare av ytterligare jobbannonser.Västra Götalandsregionen har upphandlade avtal.   ',
#   'text_formatted': None},
#  'driving_license': None,
#  'driving_license_required': None,
#  'duration': {'concept_id': None,
#   'label': 'TILLSVIDARE',
#   'legacy_ams_taxonomy_id': None},
#  'employer': {'email': None,
#   'name': 'Västra Götalands Läns Landsting',
#   'organization_number': None,
#   'phone_number': None,
#   'url': None,
#   'workplace': 'Koncernkontoret, VGR IT, Administrativa system, Arkitektur & Integration'},
#  'employment_type': {'concept_id': None,
#   'label': 'VANLIG_ANSTALLNING',
#   'legacy_ams_taxonomy_id': None},
#  'experience_required': None,
#  'external_id': '46-232100-0131-226557',
#  'headline': 'Test',
#  'id': 7923032,
#  'last_publication_date': '2019-01-02 23:59:59,000000000',
#  'logo_url': None,
#  'must_have': {'languages': None, 'skills': None, 'work_experiences': None},
#  'nice_to_have': {'languages': None, 'skills': None, 'work_experiences': None},
#  'number_of_vacancies': 1,
#  'occupation': {'concept_id': None,
#   'label': None,
#   'legacy_ams_taxonomy_id': '3097'},
#  'occupation_field': {'concept_id': None,
#   'label': None,
#   'legacy_ams_taxonomy_id': None},
#  'occupation_group': {'concept_id': None,
#   'label': None,
#   'legacy_ams_taxonomy_id': None},
#  'publication_date': '2019-01-01 00:00:00,000000000',
#  'removed': None,
#  'removed_date': None,
#  'salary_description': 'Fast månadslön',
#  'salary_type': {'concept_id': None,
#   'label': 'FAST_LON',
#   'legacy_ams_taxonomy_id': None},
#  'scope_of_work': {'max': None, 'min': None},
#  'source_type': None,
#  'timestamp': None,
#  'webpage_url': None,
#  'working_hours_type': {'concept_id': None,
#   'label': 'HELTID',
#   'legacy_ams_taxonomy_id': None},
#  'workplace_address': {'city': 'Göteborg',
#   'coordinates': None,
#   'country': 'SE',
#   'country_code': None,
#   'country_concept_id': None,
#   'municipality': None,
#   'municipality_code': None,
#   'municipality_concept_id': None,
#   'postcode': '40544',
#   'region': None,
#   'region_code': None,
#   'region_concept_id': None,
#   'street_address': 'Lillhagsparken 5'}}

# %%
af_19_df = pd.DataFrame(af_19)

# %%
af_19_df.sample(5)
# Out:
#        access access_to_own_car           application_deadline  \
# 231465   None              None  2019-05-25 23:59:59,000000000
# 185635   None              None  2019-09-19 23:59:59,000000000
# 347384   None              None  2019-08-25 23:59:59,000000000
# 462929   None              None  2019-09-30 23:59:59,000000000
# 509230   None              None  2019-10-27 23:59:59,000000000
#
#                                       application_details  \
# 231465  {'email': None, 'information': None, 'other': ...
# 185635  {'email': None, 'information': None, 'other': ...
# 347384  {'email': None, 'information': None, 'other': ...
# 462929  {'email': None, 'information': None, 'other': ...
# 509230  {'email': None, 'information': None, 'other': ...
#
#                                               description driving_license  \
# 231465  {'company_information': '', 'needs': None, 're...            None
# 185635  {'company_information': '', 'conditions': 'Hel...            None
# 347384  {'company_information': '', 'conditions': '-
# ...            None
# 462929  {'company_information': '', 'needs': None, 're...            None
# 509230  {'company_information': '', 'conditions': 'Til...            None
#
#        driving_license_required  \
# 231465                     None
# 185635                     None
# 347384                     None
# 462929                     None
# 509230                     None
#
#                                                  duration  \
# 231465  {'concept_id': None, 'label': 'ELVA_DAGAR_TILL...
# 185635  {'concept_id': None, 'label': 'TRE_TILL_SEX_MA...
# 347384  {'concept_id': None, 'label': 'TILLSVIDARE', '...
# 462929  {'concept_id': None, 'label': 'TILLSVIDARE', '...
# 509230  {'concept_id': None, 'label': 'TILLSVIDARE', '...
#
#                                                  employer  \
# 231465  {'email': None, 'name': 'Arla Foods AB', 'orga...
# 185635  {'email': None, 'name': 'Workency', 'organizat...
# 347384  {'email': None, 'name': 'Vittraskolorna AB', '...
# 462929  {'email': None, 'name': 'Linto AB', 'organizat...
# 509230  {'email': None, 'name': 'Uppsala Läns Landstin...
#
#                                           employment_type  ... removed  \
# 231465  {'concept_id': None, 'label': 'SOMMARJOBB', 'l...  ...    None
# 185635  {'concept_id': None, 'label': 'VANLIG_ANSTALLN...  ...    None
# 347384  {'concept_id': None, 'label': 'VANLIG_ANSTALLN...  ...    None
# 462929  {'concept_id': None, 'label': 'VANLIG_ANSTALLN...  ...    None
# 509230  {'concept_id': None, 'label': 'VANLIG_ANSTALLN...  ...    None
#
#        removed_date          salary_description  \
# 231465         None                         NaN
# 185635         None  Lön enligt överenskommelse
# 347384         None      Enligt överenskommelse
# 462929         None                         NaN
# 509230         None                           -
#
#                                               salary_type  \
# 231465  {'concept_id': None, 'label': 'FAST_LON', 'leg...
# 185635  {'concept_id': None, 'label': 'FAST_LON', 'leg...
# 347384  {'concept_id': None, 'label': 'FAST_LON', 'leg...
# 462929  {'concept_id': None, 'label': 'FAST_LON', 'leg...
# 509230  {'concept_id': None, 'label': 'FAST_LON', 'leg...
#
#                      scope_of_work source_type timestamp webpage_url  \
# 231465  {'max': None, 'min': None}        None      None        None
# 185635  {'max': None, 'min': None}        None      None        None
# 347384  {'max': None, 'min': None}        None      None        None
# 462929  {'max': None, 'min': None}        None      None        None
# 509230  {'max': None, 'min': None}        None      None        None
#
#                                        working_hours_type  \
# 231465  {'concept_id': None, 'label': 'HELTID', 'legac...
# 185635  {'concept_id': None, 'label': 'HELTID', 'legac...
# 347384  {'concept_id': None, 'label': 'HELTID', 'legac...
# 462929  {'concept_id': None, 'label': 'HELTID', 'legac...
# 509230  {'concept_id': None, 'label': 'HELTID', 'legac...
#
#                                         workplace_address
# 231465  {'coordinates': None, 'country_code': None, 'c...
# 185635  {'city': 'Kista', 'coordinates': None, 'countr...
# 347384  {'city': 'Stockholm', 'coordinates': None, 'co...
# 462929  {'coordinates': None, 'country_code': None, 'c...
# 509230  {'city': 'Uppsala', 'coordinates': None, 'coun...
#
# [5 rows x 33 columns]

# %%
af_19_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640257 entries, 0 to 640256
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   access                    0 non-null       object
#  1   access_to_own_car         0 non-null       object
#  2   application_deadline      640257 non-null  object
#  3   application_details       640257 non-null  object
#  4   description               640257 non-null  object
#  5   driving_license           0 non-null       object
#  6   driving_license_required  0 non-null       object
#  7   duration                  640257 non-null  object
#  8   employer                  640257 non-null  object
#  9   employment_type           640257 non-null  object
#  10  experience_required       0 non-null       object
#  11  external_id               475031 non-null  object
#  12  headline                  640257 non-null  object
#  13  id                        640257 non-null  int64
#  14  last_publication_date     640257 non-null  object
#  15  logo_url                  0 non-null       object
#  16  must_have                 640257 non-null  object
#  17  nice_to_have              640257 non-null  object
#  18  number_of_vacancies       640257 non-null  int64
#  19  occupation                640257 non-null  object
#  20  occupation_field          640257 non-null  object
#  21  occupation_group          640257 non-null  object
#  22  publication_date          640257 non-null  object
#  23  removed                   0 non-null       object
#  24  removed_date              0 non-null       object
#  25  salary_description        479854 non-null  object
#  26  salary_type               640257 non-null  object
#  27  scope_of_work             640257 non-null  object
#  28  source_type               0 non-null       object
#  29  timestamp                 0 non-null       object
#  30  webpage_url               0 non-null       object
#  31  working_hours_type        640257 non-null  object
#  32  workplace_address         640257 non-null  object
# dtypes: int64(2), object(31)
# memory usage: 161.2+ MB

# %% [markdown]
# Vi vill gärna expandera columner som är nested-dicts

# %%
def expand_dict(df, col_name):
    
    if type(df[col_name].values[0]) == dict:
        col_df = pd.DataFrame(df[col_name].values.tolist())
        names = {name: col_name + "_" + name for name in list(col_df)}
        col_df = col_df.rename(names, axis=1)
        return col_df
    else:
        return None
    
def expand_cols(df_r):
    df = df_r.copy()
    old_cols = []
    while old_cols != list(df):
        old_cols = list(df)
        for col_name in list(df):
            col_df = expand_dict(df, col_name)
            if col_df is not None:
                df[list(col_df)] = col_df
                df = df.drop(col_name, axis = 1)
    return df

df = expand_cols(af_19_df)
df
# Out:
#        access access_to_own_car           application_deadline  \
# 0        None              None  2019-01-02 23:59:59,000000000
# 1        None              None  2019-02-01 23:59:59,000000000
# 2        None              None  2019-01-20 23:59:59,000000000
# 3        None              None  2019-01-31 23:59:59,000000000
# 4        None              None  2019-04-30 23:59:59,000000000
# ...       ...               ...                            ...
# 640252   None              None  2020-01-15 23:59:59,000000000
# 640253   None              None  2020-01-30 23:59:59,000000000
# 640254   None              None  2020-01-31 23:59:59,000000000
# 640255   None              None  2020-01-17 23:59:59,000000000
# 640256   None              None  2020-01-17 23:59:59,000000000
#
#        driving_license driving_license_required experience_required  \
# 0                 None                     None                None
# 1                 None                     None                None
# 2                 None                     None                None
# 3                 None                     None                None
# 4                 None                     None                None
# ...                ...                      ...                 ...
# 640252            None                     None                None
# 640253            None                     None                None
# 640254            None                     None                None
# 640255            None                     None                None
# 640256            None                     None                None
#
#                                             external_id  \
# 0                                 46-232100-0131-226557
# 1                                                  None
# 2                                 46-232100-0131-239397
# 3       46-212000-0043-45519248EAA542FFB5E4D344CA8C2722
# 4       46-212000-2742-BECC3E0C5C904B519EADD691583E3BFB
# ...                                                 ...
# 640252                          46-556846-0066-801960-3
# 640253                   46-556618-3686-2440661-4182-gb
# 640254                            46-556788-8937-270226
# 640255                            46-556035-4309-167799
# 640256                            46-556035-4309-167800
#
#                                                  headline        id  \
# 0                                                    Test   7923032
# 1       Sommarjobb socionom/kolloledare sökes till Dju...  22877199
# 2                                              Enhetschef   8042805
# 3                        Timvikarier till Vård och Omsorg   8050451
# 4              Leg sjuksköterskor – semestervikarier 2019   8038926
# ...                                                   ...       ...
# 640252  Content Manager with love for project manageme...  23760175
# 640253  Full-stack developer for the world&#39;s leadi...  23760187
# 640254                        IT konsult till Hannells IT  23760190
# 640255                   Lärare i Idrott och Hälsa åk 6-9  23760191
# 640256                         Lärare i musik till åk 6-9  23760192
#
#                 last_publication_date  ... workplace_address_country_code  \
# 0       2019-01-02 23:59:59,000000000  ...                           None
# 1       2019-02-01 23:59:59,000000000  ...                           None
# 2       2019-01-20 23:59:59,000000000  ...                           None
# 3       2019-01-31 23:59:59,000000000  ...                           None
# 4       2019-04-30 23:59:59,000000000  ...                           None
# ...                               ...  ...                            ...
# 640252  2020-01-15 23:59:59,000000000  ...                           None
# 640253  2020-01-30 23:59:59,000000000  ...                           None
# 640254  2020-01-31 23:59:59,000000000  ...                           None
# 640255  2020-01-17 23:59:59,000000000  ...                           None
# 640256  2020-01-17 23:59:59,000000000  ...                           None
#
#         workplace_address_country_concept_id workplace_address_municipality  \
# 0                                       None                           None
# 1                                       None                           None
# 2                                       None                           None
# 3                                       None                           None
# 4                                       None                           None
# ...                                      ...                            ...
# 640252                                  None                           None
# 640253                                  None                           None
# 640254                                  None                           None
# 640255                                  None                           None
# 640256                                  None                           None
#
#        workplace_address_municipality_code  \
# 0                                     None
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
# ...                                    ...
# 640252                                None
# 640253                                None
# 640254                                None
# 640255                                None
# 640256                                None
#
#        workplace_address_municipality_concept_id workplace_address_postcode  \
# 0                                           None                      40544
# 1                                           None                      12138
# 2                                           None                      42250
# 3                                           None                      17780
# 4                                           None                      97185
# ...                                          ...                        ...
# 640252                                      None                      11129
# 640253                                      None                      11122
# 640254                                      None                      30242
# 640255                                      None                      10124
# 640256                                      None                      10124
#
#        workplace_address_region workplace_address_region_code  \
# 0                          None                          None
# 1                          None                          None
# 2                          None                          None
# 3                          None                          None
# 4                          None                          None
# ...                         ...                           ...
# 640252                     None                          None
# 640253                     None                          None
# 640254                     None                          None
# 640255                     None                          None
# 640256                     None                          None
#
#        workplace_address_region_concept_id workplace_address_street_address
# 0                                     None                 Lillhagsparken 5
# 1                                     None              Olaus Magnus väg 62
# 2                                     None                 Lillhagsparken 6
# 3                                     None                         Järfälla
# 4                                     None                   Rådstugatan 11
# ...                                    ...                              ...
# 640252                                None                     Stortorget 3
# 640253                                None                   Kungsgatan 66
# 640254                                None                    Kyrkogatan 21
# 640255                                None                          Box 213
# 640256                                None                          Box 213
#
# [640257 rows x 79 columns]

# %%
high_na = (df.isna().sum() >= int(df.shape[0]*4/5))

na_cols = list(high_na[high_na == True].index)
print(na_cols)
print(len(na_cols))
# Out:
# ['access', 'access_to_own_car', 'driving_license', 'driving_license_required', 'experience_required', 'logo_url', 'removed', 'removed_date', 'source_type', 'timestamp', 'webpage_url', 'application_details_email', 'application_details_information', 'application_details_other', 'application_details_reference', 'application_details_via_af', 'description_needs', 'description_requirements', 'description_text_formatted', 'duration_concept_id', 'duration_legacy_ams_taxonomy_id', 'employer_email', 'employer_organization_number', 'employer_phone_number', 'employer_url', 'employment_type_concept_id', 'employment_type_legacy_ams_taxonomy_id', 'must_have_languages', 'must_have_skills', 'must_have_work_experiences', 'nice_to_have_languages', 'nice_to_have_skills', 'nice_to_have_work_experiences', 'occupation_concept_id', 'occupation_label', 'occupation_field_concept_id', 'occupation_field_label', 'occupation_field_legacy_ams_taxonomy_id', 'occupation_group_concept_id', 'occupation_group_label', 'occupation_group_legacy_ams_taxonomy_id', 'salary_type_concept_id', 'salary_type_legacy_ams_taxonomy_id', 'scope_of_work_max', 'scope_of_work_min', 'working_hours_type_concept_id', 'working_hours_type_legacy_ams_taxonomy_id', 'workplace_address_coordinates', 'workplace_address_country_code', 'workplace_address_country_concept_id', 'workplace_address_municipality', 'workplace_address_municipality_code', 'workplace_address_municipality_concept_id', 'workplace_address_region', 'workplace_address_region_code', 'workplace_address_region_concept_id']
# 56

# %%
df = df.drop(na_cols, axis = 1) # more than 4/5 are None

# %%
df
# Out:
#                  application_deadline  \
# 0       2019-01-02 23:59:59,000000000
# 1       2019-02-01 23:59:59,000000000
# 2       2019-01-20 23:59:59,000000000
# 3       2019-01-31 23:59:59,000000000
# 4       2019-04-30 23:59:59,000000000
# ...                               ...
# 640252  2020-01-15 23:59:59,000000000
# 640253  2020-01-30 23:59:59,000000000
# 640254  2020-01-31 23:59:59,000000000
# 640255  2020-01-17 23:59:59,000000000
# 640256  2020-01-17 23:59:59,000000000
#
#                                             external_id  \
# 0                                 46-232100-0131-226557
# 1                                                  None
# 2                                 46-232100-0131-239397
# 3       46-212000-0043-45519248EAA542FFB5E4D344CA8C2722
# 4       46-212000-2742-BECC3E0C5C904B519EADD691583E3BFB
# ...                                                 ...
# 640252                          46-556846-0066-801960-3
# 640253                   46-556618-3686-2440661-4182-gb
# 640254                            46-556788-8937-270226
# 640255                            46-556035-4309-167799
# 640256                            46-556035-4309-167800
#
#                                                  headline        id  \
# 0                                                    Test   7923032
# 1       Sommarjobb socionom/kolloledare sökes till Dju...  22877199
# 2                                              Enhetschef   8042805
# 3                        Timvikarier till Vård och Omsorg   8050451
# 4              Leg sjuksköterskor – semestervikarier 2019   8038926
# ...                                                   ...       ...
# 640252  Content Manager with love for project manageme...  23760175
# 640253  Full-stack developer for the world&#39;s leadi...  23760187
# 640254                        IT konsult till Hannells IT  23760190
# 640255                   Lärare i Idrott och Hälsa åk 6-9  23760191
# 640256                         Lärare i musik till åk 6-9  23760192
#
#                 last_publication_date  number_of_vacancies  \
# 0       2019-01-02 23:59:59,000000000                    1
# 1       2019-02-01 23:59:59,000000000                    3
# 2       2019-01-20 23:59:59,000000000                    1
# 3       2019-01-31 23:59:59,000000000                   10
# 4       2019-04-30 23:59:59,000000000                    8
# ...                               ...                  ...
# 640252  2020-01-15 23:59:59,000000000                    1
# 640253  2020-01-30 23:59:59,000000000                    1
# 640254  2020-01-31 23:59:59,000000000                    2
# 640255  2020-01-17 23:59:59,000000000                    1
# 640256  2020-01-17 23:59:59,000000000                    1
#
#                      publication_date  \
# 0       2019-01-01 00:00:00,000000000
# 1       2019-01-01 00:00:00,000000000
# 2       2019-01-01 00:00:00,000000000
# 3       2019-01-01 00:00:00,000000000
# 4       2019-01-01 00:00:00,000000000
# ...                               ...
# 640252  2019-12-31 15:55:27,239000000
# 640253  2019-12-31 17:30:33,273000000
# 640254  2019-12-31 18:05:13,523000000
# 640255  2019-12-31 18:17:03,268000000
# 640256  2019-12-31 18:22:03,242000000
#
#                                        salary_description  \
# 0                                          Fast månadslön
# 1       Fast månadslön, individuell lönesättning tillä...
# 2                                          Fast månadslön
# 3                                                  Timlön
# 4                                           Enligt avtal.
# ...                                                   ...
# 640252                         Lön enligt överenskommelse
# 640253                                       Enligt avtal
# 640254                                           Fast lön
# 640255                             Enligt överenskommelse
# 640256                             Enligt överenskommelse
#
#                                   application_details_url  \
# 0       https://vgregion.mynetworkglobal.com/what:job/...
# 1             http://www.utepedagogik.se/sommarjobb/ansok
# 2       https://vgregion.mynetworkglobal.com/what:job/...
# 3       https://recruit.visma.com/Public/Apply.aspx?gu...
# 4       https://recruit.visma.com/Public/Apply.aspx?gu...
# ...                                                   ...
# 640252  https://jobb.sasongspersonal.se/jobs/801960-co...
# 640253  https://multimind.easycruit.com/vacancy/applic...
# 640254  https://awurval.varbi.com/what:job/jobID:27022...
# 640255  http://www.pysslingen.se/arbeta-hos-oss?aguid=...
# 640256  http://www.pysslingen.se/arbeta-hos-oss?aguid=...
#
#                           description_company_information  ...  \
# 0                                                          ...
# 1       Utepedagogik Sverige AB bedriver kollo/lägerve...  ...
# 2                                                          ...
# 3                                                          ...
# 4                                                          ...
# ...                                                   ...  ...
# 640252                                                     ...
# 640253                                                     ...
# 640254                                                     ...
# 640255                                                     ...
# 640256                                                     ...
#
#                              employer_name  \
# 0          Västra Götalands Läns Landsting
# 1                  Utepedagogik Sverige AB
# 2          Västra Götalands Läns Landsting
# 3                          Järfälla kommun
# 4                             Luleå kommun
# ...                                    ...
# 640252                       Watersheds AB
# 640253                MultiMind Holding AB
# 640254                         Aw Urval AB
# 640255  Pysslingen Förskolor och Skolor AB
# 640256  Pysslingen Förskolor och Skolor AB
#
#                                        employer_workplace  \
# 0       Koncernkontoret, VGR IT, Administrativa system...
# 1                         UTEPEDAGOGIK SVERIGE AKTIEBOLAG
# 2                     Närhälsan Olskroken rehabmottagning
# 3                               Järfälla kommun, Vakansen
# 4                       Luleå kommun, Socialförvaltningen
# ...                                                   ...
# 640252                                 Sasongspersonal.se
# 640253      MultiMind Bemanning AB MultiMind Bemanning AB
# 640254                                        AW Urval AB
# 640255                                  Pysslingen Skolor
# 640256                                  Pysslingen Skolor
#
#        employment_type_label occupation_legacy_ams_taxonomy_id  \
# 0         VANLIG_ANSTALLNING                              3097
# 1                 SOMMARJOBB                              7502
# 2         VANLIG_ANSTALLNING                              7305
# 3         VANLIG_ANSTALLNING                              7586
# 4                 SOMMARJOBB                              7296
# ...                      ...                               ...
# 640252    VANLIG_ANSTALLNING                              6314
# 640253    VANLIG_ANSTALLNING                              7633
# 640254    VANLIG_ANSTALLNING                              6625
# 640255    VANLIG_ANSTALLNING                              7654
# 640256    VANLIG_ANSTALLNING                              7654
#
#        salary_type_label working_hours_type_label workplace_address_city  \
# 0               FAST_LON                   HELTID               Göteborg
# 1               FAST_LON                   HELTID            Johanneshov
# 2               FAST_LON                   HELTID          Hisings backa
# 3               FAST_LON                   DELTID               JÄRFÄLLA
# 4               FAST_LON                   HELTID                  Luleå
# ...                  ...                      ...                    ...
# 640252          FAST_LON                   HELTID              Stockholm
# 640253          FAST_LON                   HELTID              Stockholm
# 640254          FAST_LON                   HELTID               Halmstad
# 640255          FAST_LON                   HELTID              Stockholm
# 640256          FAST_LON                   HELTID              Stockholm
#
#        workplace_address_country workplace_address_postcode  \
# 0                             SE                      40544
# 1                             SE                      12138
# 2                             SE                      42250
# 3                             SE                      17780
# 4                             SE                      97185
# ...                          ...                        ...
# 640252                        SE                      11129
# 640253                        SE                      11122
# 640254                        SE                      30242
# 640255                        SE                      10124
# 640256                        SE                      10124
#
#        workplace_address_street_address
# 0                      Lillhagsparken 5
# 1                   Olaus Magnus väg 62
# 2                      Lillhagsparken 6
# 3                              Järfälla
# 4                        Rådstugatan 11
# ...                                 ...
# 640252                     Stortorget 3
# 640253                   Kungsgatan 66
# 640254                    Kyrkogatan 21
# 640255                          Box 213
# 640256                          Box 213
#
# [640257 rows x 23 columns]

# %% [markdown]
# Vi behöver även fixa time-stamps

# %%
ts_cols = ['application_deadline', 'last_publication_date', 'publication_date']

# %%
df['application_deadline'] = pd.to_datetime(df['application_deadline'], errors='coerce')

# %%
df['last_publication_date'] = pd.to_datetime(df['last_publication_date'], errors='coerce')

# %%
df['publication_date'] = pd.to_datetime(df['publication_date'], errors='coerce')

# %% [markdown]
# ### Save our df to hdf

# %%
df.head(0).to_csv('af_prepro.csv')

# %%
def append_iter_csv(df, name):
    chunks = int(df.shape[0] / 1000)
    for chunk in tqdm(np.array_split(df, chunks)):
        chunk.to_csv(name, mode='a', header=False)
        
append_iter_csv(df, 'af_prepro.csv')
# Out:
# 100%|██████████| 640/640 [01:15<00:00,  8.49it/s]
